# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
imgplot = plt.imshow(X_train[5])
plt.show()

# %%
#Resize ảnh
X_train, X_test = X_train/255.0 , X_test/255.0

#in dataset
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1)

# %% [markdown]
# # Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization

np.random.seed(1000)

#Khởi tạo
AlexNet = Sequential()

#Block 1
AlexNet.add(Conv2D(filters=96, input_shape=(32,32,3), kernel_size=(11,11), strides=(4,4), padding='same')) #padding ="same" nghĩa là giữ 
                                                                                                        #nguyên kích thước ban đầu của input
AlexNet.add(Activation('relu')) #Có thể bỏ activation vào layer Conv như bài thực hành 1 cũng được
AlexNet.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same')) #Overlapping MaxPooling

#Block 2
AlexNet.add(Conv2D(filters=256, kernel_size=(5, 5), strides=(1,1), padding='same'))
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'))

#Block 3
AlexNet.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet.add(Activation('relu'))

#Block 4
AlexNet.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet.add(Activation('relu'))

#Block 5
AlexNet.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'))

#Flatten
AlexNet.add(Flatten())
# Lớp Fc1
AlexNet.add(Dense(4096))
AlexNet.add(Activation('relu'))
# Dropout
AlexNet.add(Dropout(rate=0.4))# rate: xác suất bị drop

#Lớp Fc2
AlexNet.add(Dense(4096))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
#Dropout
AlexNet.add(Dropout(rate=0.4))

#Lớp Fc3
AlexNet.add(Dense(1000))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
#Dropout
AlexNet.add(Dropout(rate=0.4))

#Lớp cuối cùng
AlexNet.add(Dense(10))
AlexNet.add(Activation('softmax'))

#Model Summary
AlexNet.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_44 (Conv2D)           (None, 8, 8, 96)          34944
# _________________________________________________________________
# activation_11 (Activation)   (None, 8, 8, 96)          0
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 4, 4, 96)          0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 4, 4, 256)         614656
# _________________________________________________________________
# activation_12 (Activation)   (None, 4, 4, 256)         0
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 2, 2, 384)         885120
# _________________________________________________________________
# activation_13 (Activation)   (None, 2, 2, 384)         0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 2, 2, 384)         1327488
# _________________________________________________________________
# activation_14 (Activation)   (None, 2, 2, 384)         0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 2, 2, 256)         884992
# _________________________________________________________________
# activation_15 (Activation)   (None, 2, 2, 256)         0
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 4096)              1052672
# _________________________________________________________________
# activation_16 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 4096)              16781312
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 4096)              16384
# _________________________________________________________________
# activation_17 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 4096)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1000)              4097000
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1000)              4000
# _________________________________________________________________
# activation_18 (Activation)   (None, 1000)              0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 1000)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                10010
# _________________________________________________________________
# activation_19 (Activation)   (None, 10)                0
# =================================================================
# Total params: 25,708,578
# Trainable params: 25,698,386
# Non-trainable params: 10,192
# _________________________________________________________________

# %% [markdown]
# Ta có 2 loại losses cho bài toán classification là - - categorical_crossentropy và sparse_categorical_crossentropy
#
# - categorical_crossentropy nhận label dạng onehot
# sparse_categorical_crossentropy nhận label dạng các chữ số

# %%
AlexNet.compile(loss = tf.keras.losses.sparse_categorical_crossentropy, 
                optimizer= tf.keras.optimizers.Adam(learning_rate=5e-5), metrics=['accuracy'])

# %%
### Tạo một callback ModelCheckpoint: callback này sẽ lưu model mỗi khi tìm được một model tốt hơn
#### filepath: đường dẫn file muốn lưu
#### monitor: đại lượng quyết định xem model có "tốt hơn" hay không
#### mode='auto'/'max'/'min': đại lượng monitor lớn hay nhỏ là tốt hơn
#### verbose: có thông báo mỗi lần lưu ko
#### save_best_only: chỉ lưu model tốt nhất
mc = keras.callbacks.ModelCheckpoint(filepath="epoch: {epoch:02d}.hdf5", 
                                     monitor='val_loss',
                                     mode='min', 
                                     verbose=0,
                                     save_best_only=False)

## Train  ## Khuyến cáo chạy COLAB (hoặc tương tự)
history = AlexNet.fit(X_train, y_train,
                    batch_size=512,
                    epochs=30,
                    validation_data=(X_valid, y_valid),
                    callbacks=[mc])         ##sử dụng callback ModelCheckpoint trong quá trình train
# Out:
# Epoch 1/30
# 88/88 [==============================] - 49s 176ms/step - loss: 2.0126 - accuracy: 0.2777 - val_loss: 2.2975 - val_accuracy: 0.0998
# Epoch 2/30
# 88/88 [==============================] - 12s 131ms/step - loss: 1.5462 - accuracy: 0.4313 - val_loss: 2.2853 - val_accuracy: 0.1064
# Epoch 3/30
# 88/88 [==============================] - 12s 132ms/step - loss: 1.3981 - accuracy: 0.4916 - val_loss: 2.2585 - val_accuracy: 0.2180
# Epoch 4/30
# 88/88 [==============================] - 12s 132ms/step - loss: 1.2941 - accuracy: 0.5334 - val_loss: 2.1841 - val_accuracy: 0.3742
# Epoch 5/30
# 88/88 [==============================] - 12s 133ms/step - loss: 1.2118 - accuracy: 0.5636 - val_loss: 2.0223 - val_accuracy: 0.4680
# Epoch 6/30
# 88/88 [==============================] - 12s 134ms/step - loss: 1.1374 - accuracy: 0.5929 - val_loss: 1.7782 - val_accuracy: 0.4450
# Epoch 7/30
# 88/88 [==============================] - 12s 135ms/step - loss: 1.0827 - accuracy: 0.6121 - val_loss: 1.3849 - val_accuracy: 0.5698
# Epoch 8/30
# 88/88 [==============================] - 12s 134ms/step - loss: 1.0130 - accuracy: 0.6404 - val_loss: 1.3171 - val_accuracy: 0.5294
# Epoch 9/30
# 88/88 [==============================] - 12s 135ms/step - loss: 0.9527 - accuracy: 0.6629 - val_loss: 1.2774 - val_accuracy: 0.5422
# Epoch 10/30
# 88/88 [==============================] - 12s 135ms/step - loss: 0.8907 - accuracy: 0.6839 - val_loss: 1.1665 - val_accuracy: 0.5988
# Epoch 11/30
# 88/88 [==============================] - 12s 135ms/step - loss: 0.8290 - accuracy: 0.7076 - val_loss: 1.2292 - val_accuracy: 0.5882
# Epoch 12/30
# 88/88 [==============================] - 12s 135ms/step - loss: 0.7663 - accuracy: 0.7324 - val_loss: 1.3894 - val_accuracy: 0.5544
# Epoch 13/30
# 88/88 [==============================] - 12s 135ms/step - loss: 0.7052 - accuracy: 0.7516 - val_loss: 1.3365 - val_accuracy: 0.5712
# Epoch 14/30
# 88/88 [==============================] - 12s 135ms/step - loss: 0.6500 - accuracy: 0.7711 - val_loss: 1.2216 - val_accuracy: 0.6098
# Epoch 15/30
# 88/88 [==============================] - 12s 135ms/step - loss: 0.5786 - accuracy: 0.7986 - val_loss: 1.3112 - val_accuracy: 0.6058
# Epoch 16/30
# 88/88 [==============================] - 12s 135ms/step - loss: 0.5272 - accuracy: 0.8159 - val_loss: 1.3892 - val_accuracy: 0.6064
# Epoch 17/30
# 88/88 [==============================] - 12s 135ms/step - loss: 0.4692 - accuracy: 0.8371 - val_loss: 1.4656 - val_accuracy: 0.5970
# Epoch 18/30
# 88/88 [==============================] - 12s 135ms/step - loss: 0.4164 - accuracy: 0.8565 - val_loss: 1.5690 - val_accuracy: 0.5970
# Epoch 19/30
# 88/88 [==============================] - 12s 135ms/step - loss: 0.3613 - accuracy: 0.8739 - val_loss: 1.6163 - val_accuracy: 0.6034
# Epoch 20/30
# 88/88 [==============================] - 12s 136ms/step - loss: 0.3058 - accuracy: 0.8951 - val_loss: 1.7766 - val_accuracy: 0.5842
# Epoch 21/30
# 88/88 [==============================] - 12s 136ms/step - loss: 0.2748 - accuracy: 0.9051 - val_loss: 1.7761 - val_accuracy: 0.6014
# Epoch 22/30
# 88/88 [==============================] - 12s 136ms/step - loss: 0.2371 - accuracy: 0.9186 - val_loss: 2.0665 - val_accuracy: 0.5792
# Epoch 23/30
# 88/88 [==============================] - 12s 135ms/step - loss: 0.2022 - accuracy: 0.9306 - val_loss: 2.0784 - val_accuracy: 0.5850
# Epoch 24/30
# 88/88 [==============================] - 12s 136ms/step - loss: 0.1696 - accuracy: 0.9410 - val_loss: 2.0634 - val_accuracy: 0.5932
# Epoch 25/30
# 88/88 [==============================] - 12s 136ms/step - loss: 0.1576 - accuracy: 0.9452 - val_loss: 2.2390 - val_accuracy: 0.5800
# Epoch 26/30
# 88/88 [==============================] - 12s 136ms/step - loss: 0.1341 - accuracy: 0.9553 - val_loss: 2.1370 - val_accuracy: 0.6040
# Epoch 27/30
# 88/88 [==============================] - 12s 136ms/step - loss: 0.1001 - accuracy: 0.9656 - val_loss: 2.3012 - val_accuracy: 0.6060
# Epoch 28/30
# 88/88 [==============================] - 12s 136ms/step - loss: 0.1205 - accuracy: 0.9586 - val_loss: 2.3710 - val_accuracy: 0.5894
# Epoch 29/30
# 88/88 [==============================] - 12s 135ms/step - loss: 0.0906 - accuracy: 0.9696 - val_loss: 2.4516 - val_accuracy: 0.6014
# Epoch 30/30
# 88/88 [==============================] - 12s 135ms/step - loss: 0.0833 - accuracy: 0.9718 - val_loss: 2.5752 - val_accuracy: 0.5942

# %% [markdown]
# # Train

# %%
#Vẽ thử đồ thị

f,ax=plt.subplots(2,1) 


ax[0].plot(history.history['loss'],color='b',label='Training Loss')
ax[0].plot(history.history['val_loss'],color='r',label='Validation Loss')


ax[1].plot(history.history['accuracy'],color='b',label='Training  Accuracy')
ax[1].plot(history.history['val_accuracy'],color='r',label='Validation Accuracy')

plt.legend()

# %%
#ta chọn epoch thứ 10 làm best model
model = tf.keras.models.load_model("/content/epoch: 10.hdf5")
result = AlexNet.evaluate(X_test,y_test)
print("loss và accuracy trên tập test là {} {}".format(result[0],result[1]))
# Out:
# 313/313 [==============================] - 3s 11ms/step - loss: 2.6405 - accuracy: 0.5843
# loss và accuracy trên tập test là 2.64046573638916 0.5842999815940857

# %% [markdown]
# # Bài tập

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization

model = Sequential()
#Block 1 của mạng vgg16
model.add(tf.keras.layers.Conv2D(filters=64,
                                 input_shape=(32,32,3),
                                 kernel_size=[3,3],
                                 strides=[1,1],
                                 padding="same",
                                 activation=tf.nn.relu))
model.add(tf.keras.layers.Conv2D(filters=64,
                                 kernel_size=[3,3],
                                 strides=[1,1],
                                 padding="same",
                                 activation=tf.nn.relu))
model.add(tf.keras.layers.MaxPooling2D(pool_size=[2,2],
                                         strides=[2,2]))
#Block 2
model.add(tf.keras.layers.Conv2D(filters=128,
                                 kernel_size=[3,3],
                                 strides=[1,1],
                                 padding="same",
                                 activation=tf.nn.relu))
model.add(tf.keras.layers.Conv2D(filters=128,
                                 kernel_size=[3,3],
                                 strides=[1,1],
                                 padding="same",
                                 activation=tf.nn.relu))
model.add(tf.keras.layers.MaxPooling2D(pool_size=[2,2],
                                         strides=[2,2]))
#Block 3
model.add(tf.keras.layers.Conv2D(filters = 256,
                                 kernel_size=[3,3],
                                 strides=[1,1],
                                 padding='same',
                                 activation=tf.nn.relu))
model.add(tf.keras.layers.Conv2D(filters = 256,
                                 kernel_size=[3,3],
                                 strides=[1,1],
                                 padding='same',
                                 activation=tf.nn.relu))
model.add(tf.keras.layers.Conv2D(filters = 256,
                                 kernel_size=[3,3],
                                 strides=[1,1],
                                 padding='same',
                                 activation=tf.nn.relu))
model.add(tf.keras.layers.MaxPooling2D(pool_size=[2,2],
                                         strides=[2,2]))
#Block 4
model.add(tf.keras.layers.Conv2D(filters = 512,
                                 kernel_size=[3,3],
                                 strides=[1,1],
                                 padding='same',
                                 activation=tf.nn.relu))
model.add(tf.keras.layers.Conv2D(filters = 512,
                                 kernel_size=[3,3],
                                 strides=[1,1],
                                 padding='same',
                                 activation=tf.nn.relu))
model.add(tf.keras.layers.Conv2D(filters = 512,
                                 kernel_size=[3,3],
                                 strides=[1,1],
                                 padding='same',
                                 activation=tf.nn.relu))
model.add(tf.keras.layers.MaxPooling2D(pool_size=[2,2],
                                         strides=[2,2]))
#Block 5
model.add(tf.keras.layers.Conv2D(filters = 512,
                                 kernel_size=[3,3],
                                 strides=[1,1],
                                 padding='same',
                                 activation=tf.nn.relu))
model.add(tf.keras.layers.Conv2D(filters = 512,
                                 kernel_size=[3,3],
                                 strides=[1,1],
                                 padding='same',
                                 activation=tf.nn.relu))
model.add(tf.keras.layers.Conv2D(filters = 512,
                                 kernel_size=[3,3],
                                 strides=[1,1],
                                 padding='same',
                                 activation=tf.nn.relu))
model.add(tf.keras.layers.MaxPooling2D(pool_size=[2,2],
                                         strides=[2,2]))
#Block cuối
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(units=4096, 
                              activation='relu'))
model.add(tf.keras.layers.Dropout(rate=0.5))
#............................................
model.add(tf.keras.layers.Dense(units=4096, 
                              activation='relu'))
model.add(tf.keras.layers.Dropout(rate=0.5))

model.add(Dense(10))
model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 4, 512)         2359808
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 512)         2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2101248
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                40970
# _________________________________________________________________
# activation (Activation)      (None, 10)                0
# =================================================================
# Total params: 33,638,218
# Trainable params: 33,638,218
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = tf.keras.losses.sparse_categorical_crossentropy, 
                optimizer= tf.keras.optimizers.Adam(learning_rate=5e-5), metrics=['accuracy'])

# %%
mc = keras.callbacks.ModelCheckpoint(filepath="epoch: {epoch:02d}.hdf5", 
                                     monitor='val_loss',
                                     mode='min', 
                                     verbose=0,
                                     save_best_only=False)

## Train  ## Khuyến cáo chạy COLAB (hoặc tương tự)
history = model.fit(X_train, y_train,
                    batch_size=512,
                    epochs=30,
                    validation_data=(X_valid, y_valid),
                    callbacks=[mc])
# Out:
# Epoch 1/30
# 88/88 [==============================] - 55s 496ms/step - loss: 2.2192 - accuracy: 0.1475 - val_loss: 2.0465 - val_accuracy: 0.2082
# Epoch 2/30
# 88/88 [==============================] - 33s 380ms/step - loss: 1.9004 - accuracy: 0.2604 - val_loss: 1.7689 - val_accuracy: 0.3120
# Epoch 3/30
# 88/88 [==============================] - 34s 385ms/step - loss: 1.7239 - accuracy: 0.3241 - val_loss: 1.6511 - val_accuracy: 0.3522
# Epoch 4/30
# 88/88 [==============================] - 34s 387ms/step - loss: 1.6127 - accuracy: 0.3674 - val_loss: 1.5505 - val_accuracy: 0.3948
# Epoch 5/30
# 88/88 [==============================] - 34s 386ms/step - loss: 1.5422 - accuracy: 0.3954 - val_loss: 1.5624 - val_accuracy: 0.4000
# Epoch 6/30
# 88/88 [==============================] - 34s 387ms/step - loss: 1.4653 - accuracy: 0.4330 - val_loss: 1.4867 - val_accuracy: 0.4330
# Epoch 7/30
# 88/88 [==============================] - 34s 387ms/step - loss: 1.3808 - accuracy: 0.4723 - val_loss: 1.3744 - val_accuracy: 0.4864
# Epoch 8/30
# 88/88 [==============================] - 34s 387ms/step - loss: 1.3052 - accuracy: 0.5085 - val_loss: 1.2717 - val_accuracy: 0.5340
# Epoch 9/30
# 88/88 [==============================] - 34s 386ms/step - loss: 1.2319 - accuracy: 0.5426 - val_loss: 1.2276 - val_accuracy: 0.5418
# Epoch 10/30
# 88/88 [==============================] - 34s 384ms/step - loss: 1.1613 - accuracy: 0.5734 - val_loss: 1.1546 - val_accuracy: 0.5828
# Epoch 11/30
# 88/88 [==============================] - 34s 384ms/step - loss: 1.1054 - accuracy: 0.5975 - val_loss: 1.1368 - val_accuracy: 0.5876
# Epoch 12/30
# 88/88 [==============================] - 34s 384ms/step - loss: 1.0478 - accuracy: 0.6174 - val_loss: 1.1147 - val_accuracy: 0.5936
# Epoch 13/30
# 88/88 [==============================] - 34s 384ms/step - loss: 0.9847 - accuracy: 0.6378 - val_loss: 1.0802 - val_accuracy: 0.6034
# Epoch 14/30
# 88/88 [==============================] - 34s 383ms/step - loss: 0.9402 - accuracy: 0.6575 - val_loss: 1.0660 - val_accuracy: 0.6202
# Epoch 15/30
# 88/88 [==============================] - 34s 384ms/step - loss: 0.8822 - accuracy: 0.6819 - val_loss: 1.0933 - val_accuracy: 0.6114
# Epoch 16/30
# 88/88 [==============================] - 34s 384ms/step - loss: 0.8504 - accuracy: 0.6955 - val_loss: 1.0555 - val_accuracy: 0.6256
# Epoch 17/30
# 88/88 [==============================] - 34s 383ms/step - loss: 0.8124 - accuracy: 0.7086 - val_loss: 1.0265 - val_accuracy: 0.6414
# Epoch 18/30
# 88/88 [==============================] - 34s 384ms/step - loss: 0.7380 - accuracy: 0.7336 - val_loss: 1.0409 - val_accuracy: 0.6438
# Epoch 19/30
# 88/88 [==============================] - 34s 384ms/step - loss: 0.6881 - accuracy: 0.7527 - val_loss: 1.0742 - val_accuracy: 0.6410
# Epoch 20/30
# 88/88 [==============================] - 34s 384ms/step - loss: 0.6472 - accuracy: 0.7700 - val_loss: 1.0970 - val_accuracy: 0.6452
# Epoch 21/30
# 88/88 [==============================] - 34s 384ms/step - loss: 0.5784 - accuracy: 0.7947 - val_loss: 1.0967 - val_accuracy: 0.6524
# Epoch 22/30
# 88/88 [==============================] - 34s 382ms/step - loss: 0.5534 - accuracy: 0.8048 - val_loss: 1.1312 - val_accuracy: 0.6476
# Epoch 23/30
# 88/88 [==============================] - 34s 384ms/step - loss: 0.4799 - accuracy: 0.8319 - val_loss: 1.1579 - val_accuracy: 0.6548
# Epoch 24/30
# 88/88 [==============================] - 34s 383ms/step - loss: 0.4338 - accuracy: 0.8486 - val_loss: 1.2994 - val_accuracy: 0.6384
# Epoch 25/30
# 88/88 [==============================] - 34s 384ms/step - loss: 0.3844 - accuracy: 0.8672 - val_loss: 1.2689 - val_accuracy: 0.6582
# Epoch 26/30
# 88/88 [==============================] - 34s 384ms/step - loss: 0.3614 - accuracy: 0.8751 - val_loss: 1.3155 - val_accuracy: 0.6472
# Epoch 27/30
# 88/88 [==============================] - 34s 384ms/step - loss: 0.2978 - accuracy: 0.8999 - val_loss: 1.4330 - val_accuracy: 0.6340
# Epoch 28/30
# 88/88 [==============================] - 34s 385ms/step - loss: 0.2601 - accuracy: 0.9131 - val_loss: 1.4928 - val_accuracy: 0.6440
# Epoch 29/30
# 88/88 [==============================] - 34s 384ms/step - loss: 0.2450 - accuracy: 0.9171 - val_loss: 1.6212 - val_accuracy: 0.6358
# Epoch 30/30
# 88/88 [==============================] - 34s 384ms/step - loss: 0.2106 - accuracy: 0.9294 - val_loss: 1.5810 - val_accuracy: 0.6506

# %%
f,ax=plt.subplots(2,1) 


ax[0].plot(history.history['loss'],color='b',label='Training Loss')
ax[0].plot(history.history['val_loss'],color='r',label='Validation Loss')


ax[1].plot(history.history['accuracy'],color='b',label='Training  Accuracy')
ax[1].plot(history.history['val_accuracy'],color='r',label='Validation Accuracy')

plt.legend()

# %% [markdown]
# Chọn epoch 10 vì tại đó accuracy của train (0.5734) và valid (0.5828) xấp xỉ nhau

# %%
model = tf.keras.models.load_model("/content/epoch: 10.hdf5")
result = model.evaluate(X_test,y_test)
print("loss và accuracy trên tập test là {} {}".format(result[0],result[1]))
# Out:
# 313/313 [==============================] - 7s 21ms/step - loss: 1.1347 - accuracy: 0.5875
# loss và accuracy trên tập test là 1.134698748588562 0.5874999761581421
